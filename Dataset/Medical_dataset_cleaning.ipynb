# %%
import pandas as pd
df = pd.read_csv(r'Medical_ordered.csv', encoding='latin-1')
df.head()
# Out:
#         Title main_category category        date  \
# 0          le       Medical  Medical  2023-10-08
# 1      facial       Medical  Medical  2023-10-08
# 2        body       Medical  Medical  2023-10-08
# 3       crohn       Medical  Medical  2023-10-08
# 4  aggressive       Medical  Medical  2023-10-08
#
#                                          description
# 0  excision limbal dermoids reviewed clinical fil...
# 1  bell palsy diagnosis exclusion case acute unil...
# 2  retained endobronchial foreign body removal fa...
# 3  recurrent buccal space abscess complication cr...
# 4  intracranial fibromatosis fibromatoses uncommo...

# %%
import pandas as pd
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

stop_words = set(stopwords.words('english'))
punctuations = set(string.punctuation)

lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()
    tokens = word_tokenize(text)
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words and token not in punctuations and token.isalpha()]
    return ' '.join(tokens)  


df['description'] = df['description'].apply(preprocess_text)


df.tail()
# Out:
#            Title main_category category        date  \
# 344         cell       Medical  Medical  2023-10-08
# 345         case       Medical  Medical  2023-10-08
# 346        chest       Medical  Medical  2023-10-08
# 347  angiotensin       Medical  Medical  2023-10-08
# 348         oral       Medical  Medical  2023-10-08
#
#                                            description
# 344  characterization human renal fibroblast health...
# 345  deformity correction survival infant inienceph...
# 346  circadian variation frequency onset chest pain...
# 347  angiotensin converting enzyme inhibitor region...
# 348  premedication oral glycopyrrolate effective or...

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

# Fit and transform the 'description' column
X = vectorizer.fit_transform(df['description'])

# Find the highest frequency words in each row
max_freq_words = []
for i, description in enumerate(df['description']):
    row = X[i]
    word_idx = row.argmax()
    max_freq_word = list(vectorizer.vocabulary_.keys())[list(vectorizer.vocabulary_.values()).index(word_idx)]
    max_freq_words.append(max_freq_word)

# Add a new 'title' column to the DataFrame with the maximum frequency words
df['Title'] = max_freq_words

# %%
df['category'] = "Medical"
df['date'] = '2023-10-08'
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#         Title main_category category       date  \
# 0          le       Medical  Medical 2023-10-08
# 1      facial       Medical  Medical 2023-10-08
# 2        body       Medical  Medical 2023-10-08
# 3       crohn       Medical  Medical 2023-10-08
# 4  aggressive       Medical  Medical 2023-10-08
#
#                                          description
# 0  excision limbal dermoids reviewed clinical fil...
# 1  bell palsy diagnosis exclusion case acute unil...
# 2  retained endobronchial foreign body removal fa...
# 3  recurrent buccal space abscess complication cr...
# 4  intracranial fibromatosis fibromatoses uncommo...

# %%
#save to csv
df.to_csv('Medical_final_dataset.csv', index=False)
