# %%
import pandas as pd
df = pd.read_csv(r'D:\Personal\diksha\6 SEM\NLP-shivi\Buck\Research_Paper_Category_Dataset_v3.csv', encoding='latin-1')
df.head()
# Out:
#          id           submitter  \
# 0  704.0001      Pavel Nadolsky
# 1  704.0002        Louis Theran
# 2  704.0003         Hongjun Pan
# 3  704.0004        David Callan
# 4  704.0005  Alberto Torchinsky
#
#                                              authors  \
# 0  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                    Ileana Streinu and Louis Theran
# 2                                        Hongjun Pan
# 3                                       David Callan
# 4           Wael Abu-Shammala and Alberto Torchinsky
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1           Sparsity-certifying Graph Decompositions
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                   comments  \
# 0  37 pages, 15 figures; published version
# ...

# %%
# drop column id , submitter, authors, journal-ref. doi, report-no
df.drop(['id', 'submitter', 'authors', 'journal-ref', 'doi', 'report-no'], axis=1, inplace=True)
df.head()
# Out:
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1           Sparsity-certifying Graph Decompositions
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                   comments       categories  \
# 0  37 pages, 15 figures; published version           hep-ph
# 1    To appear in Graphs and Combinatorics    math.CO cs.CG
# 2                      23 pages, 3 figures   physics.gen-ph
# 3                                 11 pages          math.CO
# 4                                      NaN  math.CA math.FA
#
#                                              license  \
# 0                                                NaN
# 1  http://arxiv.org/licenses/nonexclusive-distrib...
# 2                                                NaN
# 3                                                NaN
# ...

# %%
#drop columns comments, license, versions, authors_parsed
df.drop(['comments', 'license', 'versions', 'authors_parsed'], axis=1, inplace=True)
df.head()
# Out:
#                                                title       categories  \
# 0  Calculation of prompt diphoton production cros...           hep-ph
# 1           Sparsity-certifying Graph Decompositions    math.CO cs.CG
# 2  The evolution of the Earth-Moon system based o...   physics.gen-ph
# 3  A determinant of Stirling cycle numbers counts...          math.CO
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...  math.CA math.FA
#
#                                             abstract update_date
# 0    A fully differential calculation in perturba...  2008-11-26
# 1    We describe a new algorithm, the $(k,\ell)$-...  2008-12-13
# 2    The evolution of Earth-Moon system is descri...  2008-01-13
# 3    We show that a determinant of Stirling cycle...  2007-05-23
# 4    In this paper we show how to compute the $\L...  2013-10-15

# %%
#preprocessing
import pandas as pd
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

stop_words = set(stopwords.words('english'))
punctuations = set(string.punctuation)

lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()
    tokens = word_tokenize(text)
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words and token not in punctuations and token.isalpha()]
    return ' '.join(tokens)  

df['title_clean'] = df['title'].apply(preprocess_text)
df['abstract_clean'] = df['abstract'].apply(preprocess_text)


df.to_csv('research_paper_dataset1.csv', index=False)

df.head()
# Out:
#                                                title       categories  \
# 0  Calculation of prompt diphoton production cros...           hep-ph
# 1           Sparsity-certifying Graph Decompositions    math.CO cs.CG
# 2  The evolution of the Earth-Moon system based o...   physics.gen-ph
# 3  A determinant of Stirling cycle numbers counts...          math.CO
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...  math.CA math.FA
#
#                                             abstract update_date  \
# 0    A fully differential calculation in perturba...  2008-11-26
# 1    We describe a new algorithm, the $(k,\ell)$-...  2008-12-13
# 2    The evolution of Earth-Moon system is descri...  2008-01-13
# 3    We show that a determinant of Stirling cycle...  2007-05-23
# 4    In this paper we show how to compute the $\L...  2013-10-15
#
#                                          title_clean  \
# 0  calculation prompt diphoton production cross s...
# ...

# %%
#drop abstract and title
df.drop(['abstract', 'title'], axis=1, inplace=True)
df.head()
# Out:
#         categories update_date  \
# 0           hep-ph  2008-11-26
# 1    math.CO cs.CG  2008-12-13
# 2   physics.gen-ph  2008-01-13
# 3          math.CO  2007-05-23
# 4  math.CA math.FA  2013-10-15
#
#                                          title_clean  \
# 0  calculation prompt diphoton production cross s...
# 1                                graph decomposition
# 2  evolution system based dark matter field fluid...
# 3  determinant stirling cycle number count unlabe...
# 4                                             dyadic
#
#                                       abstract_clean
# 0  fully differential calculation perturbative qu...
# 1  describe new algorithm k game color use obtain...
# 2  evolution system described dark matter field f...
# 3  show determinant stirling cycle number count u...
# 4  paper show compute norm using dyadic grid resu...

# %%
#adding main_category column
new_column_name = 'main_category'

#NaN values instead 
df[new_column_name] = float('nan')

# Save the updated dataset to a new CSV file
df.to_csv('research_paper_dataset2.csv', index=False)

# %%
df1 = pd.read_csv(r'D:\Personal\diksha\6 SEM\NLP-shivi\Buck\research_paper_dataset2.csv', encoding='latin-1')
df1.head()
# Out:
#         categories update_date  \
# 0           hep-ph  2008-11-26
# 1    math.CO cs.CG  2008-12-13
# 2   physics.gen-ph  2008-01-13
# 3          math.CO  2007-05-23
# 4  math.CA math.FA  2013-10-15
#
#                                          title_clean  \
# 0  calculation prompt diphoton production cross s...
# 1                                graph decomposition
# 2  evolution system based dark matter field fluid...
# 3  determinant stirling cycle number count unlabe...
# 4                                             dyadic
#
#                                       abstract_clean  main_category
# 0  fully differential calculation perturbative qu...            NaN
# 1  describe new algorithm k game color use obtain...            NaN
# 2  evolution system described dark matter field f...            NaN
# 3  show determinant stirling cycle number count u...            NaN
# 4  paper show compute norm using dyadic grid resu...            NaN

# %%
import pandas as pd

# Specify the column name to replace NaN values
column_name = 'main_category'

# Replace NaN values with 'News'
df1[column_name].fillna('Research Paper', inplace=True)

# Save the updated dataset to a new CSV file
df1.to_csv('research_paper_dataset3.csv', index=False)

# %%
df2 = pd.read_csv(r"D:\Personal\diksha\6 SEM\NLP-shivi\Buck\research_paper_dataset3.csv")
df2.head()
# Out:
#         categories update_date  \
# 0           hep-ph  2008-11-26
# 1    math.CO cs.CG  2008-12-13
# 2   physics.gen-ph  2008-01-13
# 3          math.CO  2007-05-23
# 4  math.CA math.FA  2013-10-15
#
#                                          title_clean  \
# 0  calculation prompt diphoton production cross s...
# 1                                graph decomposition
# 2  evolution system based dark matter field fluid...
# 3  determinant stirling cycle number count unlabe...
# 4                                             dyadic
#
#                                       abstract_clean   main_category
# 0  fully differential calculation perturbative qu...  Research Paper
# 1  describe new algorithm k game color use obtain...  Research Paper
# 2  evolution system described dark matter field f...  Research Paper
# 3  show determinant stirling cycle number count u...  Research Paper
# 4  paper show compute norm using dyadic grid resu...  Research Paper

# %%
#rename title_clean column to Title and make it the first column
import pandas as pd
df = pd.read_csv("combined_final_dataset.csv")

# %%
df
# Out:
#                                                  Title   main_category  \
# 0    Over 4 Million Americans Roll Up Sleeves For O...            News
# 1    American Airlines Flyer Charged, Banned For Li...            News
# 2    23 Of The Funniest Tweets About Cats And Dogs ...            News
# 3    The Funniest Tweets From Parents This Week (Se...            News
# 4    Woman Who Called Cops On Black Bird-Watcher Lo...            News
# ..                                                 ...             ...
# 380  orbital polarization transition multiorbital m...  Research Paper
# 381                         intelligent life cosmology  Research Paper
# 382      mass radius unseen companion eclipsing binary  Research Paper
# 383  coulomb excitation unstable nucleus intermedia...  Research Paper
# 384    intersection body generalized cosine transforms  Research Paper
#
#             category        date  \
# 0          U.S. NEWS  2022-09-23
# 1          U.S. NEWS  2022-09-23
# ...
